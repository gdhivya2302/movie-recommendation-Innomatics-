# %% [markdown]
# <a href="https://colab.research.google.com/github/gdhivya2302/movie-recommendation-Innomatics-/blob/coding/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('movies.csv')

# %%
df.shape
# Out:
# (9742, 3)

# %%
df.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
matrix_row = df[df['title'] == 'Matrix, The (1999)']

# %%
matrix_genres = matrix_row['genres'].iloc[0]

# %%
matrix_tags = matrix_genres.split('|')

# Print the result
print("Tags submitted by users for 'Matrix, The (1999)':", matrix_tags)
# Out:
# Tags submitted by users for 'Matrix, The (1999)': ['Action', 'Sci-Fi', 'Thriller']
